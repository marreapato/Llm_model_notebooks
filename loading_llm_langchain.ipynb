# %% [markdown]
# <a href="https://colab.research.google.com/github/marreapato/Llm_model_notebooks/blob/main/loading_llm_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain transformers einops accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 38.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 13.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import os
import torch
import transformers
from langchain.llms import HuggingFacePipeline
#from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model = "EleutherAI/gpt-neo-125m"  # or any compatible model

tokenizer = transformers.AutoTokenizer.from_pretrained(model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    max_length=512,              # increase from 200
    trust_remote_code=True,
    temperature=0.8,             # controls creativity
    top_p=0.95,                  # nucleus sampling
    top_k=50,                    # not too restrictive
    repetition_penalty=1.1      # discourages repetition
)
# Out:
# Device set to use cpu

# %%
from langchain import PromptTemplate, LLMChain

llm = HuggingFacePipeline(pipeline = pipeline)

prompt = PromptTemplate(input_variables = ['content'],
                        template = 'Tell me a story about {content}.')

chain = LLMChain(llm = llm, prompt = prompt)

print(chain.run('aliens'))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Tell me a story about aliens.
#
# This is a story about a very specific alien called “Giant Angel”. He was one of the first alien types to arrive in the U.S. and travel through the desert. He was created by a local Mexican band who happened to be visiting Texas, and they are not the first alien to appear on the show. They are the first of the aliens to arrive in the desert and travel to the border. In order to get the first glimpse of what the aliens are going through, the band had to take the opportunity to get it wrong.
#
# First, they were looking for a way to use their rocket, as opposed to an egg, to go into the desert. And that was one of the things they had to do. They needed to get out of the desert and get to the desert. The band told them that if they did not have the rocket, they would get to the desert. So they decided to take the rocket, and they took it to the desert.
#
# ...

# %%
print(chain.run('dogs'))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Tell me a story about dogs.
#
# I'm a dog lover. I love dogs. They are so fun to look at.
#
# I'm a huge proponent of animal rights. I believe that the right to bear and breed dogs is the right of all animals and their owners.
#
# I'm a proponent of the right to pets. I love to see my dog walk, play and play with her friends.
#
# I'm a proponent of the right to children. I love the ability to raise them in their own homes.
#
# I'm a proponent of the right to animals.
#
# I'm a proponent of the right to dogs.
#
# I'm a proponent of the right to cats.
#
# I'm a proponent of the right to dogs.
#
# I'm a proponent of the right to cats.
#
# I'm a proponent of the right to animals.
#
# I'm a proponent of the right to animals.
#
# I'm a proponent of the right to dogs.
#
# I'm a proponent of the right to cats.
#
# I'm a proponent of the right to dogs.
#
# I'm a proponent of the right to cats.
#
# ...
